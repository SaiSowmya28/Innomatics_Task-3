# %% [markdown]
# # 1: Employee Performance Bonus Eligibility
# Description:
# A company evaluates employee performance scores at the end of the year. You are given a dictionary containing employee names and their performance scores.
# Requirements:
# Identify the highest performance score.
# Handle ties if multiple employees have the same highest score.
# Display all employees eligible for the top performance bonus.
# Input:
# employees = {
# "Ravi": 92,
# "Anita": 88,
# "Kiran": 92,
# "Suresh": 85
# }
# Expected Output:
# Top Performers Eligible for Bonus: Ravi, Kiran (Score: 92)

# %%
# dictionary with names and performance
employees = {
"Ravi": 92,
"Anita": 88,
"Kiran": 92,
"Suresh": 85
}
# access all the perforamance in a list
performance=list(employees.values())
# high performance
high_performance=max(performance)
#looping and pairs the high performance score and employee name 
for name,performances in employees.items():
# checking the each performance with the high_performance and displaying names and score 
    if performances==high_performance:
        print(f'Top Performers Eligible for Bonus: {name}, score:{high_performance}')
# Out:
# Top Performers Eligible for Bonus: Ravi, score:92
# Top Performers Eligible for Bonus: Kiran, score:92

# %% [markdown]
# # 2: Search Query Keyword Analysis
# Description:
# An e-commerce website stores customer search queries. You are given a search query sentence entered by a user.
# Requirements:
# Convert the input to lowercase.
# Ignore common punctuation.
# Count the frequency of each keyword.
# Display only keywords searched more than once.
# Input:
# "Buy mobile phone buy phone online"
# Expected Output:
# {'buy': 2, 'phone': 2}

# %%
# import string to deal with puncutations 
import string
# search query sentence entered by a user
text=input('Enter the search query:')
# covert the sentence into lower case
text=text.lower()
# looping to remove the punctuation
for i in string.punctuation:
    text=text.replace(i,'')
# spearating the words  
words=text.split()
# empty dict 
freq={}
# looping into the each word and counts them 
for word in words:
    if word in freq: 
        freq[word]+=1
    else:
        freq[word]=1
# To find the most searched key words
result={}
for word,count in freq.items():
    if count>1:
        result[word]=count
print(result)
# Out:
# Enter the search query: "Buy mobile phone buy phone online"
# {'buy': 2, 'phone': 2}

# %% [markdown]
# # 3: Sensor Data Validation
# Description:
# A factory collects sensor readings every hour. Each reading is stored in a list where the index represents the hour and the value represents the sensor reading.
# Requirements:
# Identify readings that are even numbers (valid readings).
# Store them as (hour_index, reading_value) pairs.
# Ignore odd readings (invalid readings).
# Input:
# sensor_readings = [3, 4, 7, 8, 10, 12, 5]
# Expected Output:
# Valid Sensor Readings (Hour, Value):
# [(1, 4), (3, 8), (4, 10), (5, 12)]

# %%
sensor_readings = [3, 4, 7, 8, 10, 12, 5]
#empty list
lis=[]
#looping and validating even readings,invalidating the odd reading
for i in sensor_readings:
    if i%2==0:
        lis.append((sensor_readings.index(i),i))
print('Valid Sensor Reading (Hour, Value):\n',lis)
# Out:
# Valid Sensor Reading (Hour, Value):
#  [(1, 4), (3, 8), (4, 10), (5, 12)]

# %% [markdown]
# # 4: Email Domain Usage Analysis
# Description:
# A company wants to analyze which email providers its users are using. You are given a list of employee email IDs.
# Requirements:
# Count how many users belong to each email domain.
# Calculate the percentage usage of each domain.
# Input:
# emails = [
# "ravi@gmail.com",
# "anita@yahoo.com",
# "kiran@gmail.com",
# "suresh@gmail.com",
# "meena@yahoo.com"
# ]
# Expected Output:
# gmail.com: 60%
# yahoo.com: 40%

# %%
emails = [
"ravi@gmail.com",
"anita@yahoo.com",
"kiran@gmail.com",
"suresh@gmail.com",
"meena@yahoo.com"
]
# Intalize the empty list of two domains
gmail_domain=[]
yahoo_domain=[]
# looping and identify the domains and sperated them  
for i in emails:
    if i.endswith('@gmail.com'):
        gmail_domain.append(i)
    elif i.endswith('@yahoo.com'):
        yahoo_domain.append(i)
    else:
        print('Enter the Valid email')
# calculating the percentage of both the domains
print('gmail.com:' ,len(gmail_domain)/len(emails)*100)
print('yahoo.com:', len(yahoo_domain)/len(emails)*100)
# Out:
# gmail.com: 60.0
# yahoo.com: 40.0

# %% [markdown]
# #  5: Sales Spike Detection
# Description:
# A retail company tracks daily sales. Sudden spikes in sales may indicate promotions or unusual activity.
# Requirements:
# Calculate the average daily sales.
# Detect days where sales are more than 30% above average.
# Display the day number and sale value.
# Input:
# sales = [1200, 1500, 900, 2200, 1400, 3000]
# Expected Output:
# Day 4: 2200
# Day 6: 3000

# %%
sales = [1200, 1500, 900, 2200, 1400, 3000]
#Intalize total 
total=0
# looping each day sales and calculating the average 
for i in sales:
    total+=i
#calculate average as total/no.of sales
avg=total/len(sales)
# detecting the day where sales are more than 30% above average
condition=avg+(0.3*avg)
# loop  and compare the each day sales
for index,sale in enumerate(sales):
    if sale > condition:
        print(f' Day {index+1}:{sale}')
# Out:
#  Day 6:3000

# %% [markdown]
# # 6: Duplicate User ID Detection
# Description:
# A system stores user IDs during registration. Duplicate IDs can cause data integrity issues.
# Requirements:
# Identify duplicate user IDs.
# Display how many times each duplicate appears.
# Input:
# user_ids = ["user1", "user2", "user1", "user3", "user1", "user3"]
# Expected Output:
# user1 → 3 times
# user3 → 2 times

# %%
user_ids = ["user1", "user2", "user1", "user3", "user1", "user3"]
# empty dict 
freq={}
#loops to ccount the user ids
for i in user_ids:
    if i in freq:
        freq[i]+=1
    else:
        freq[i]=1
# loop for how many times each duplicate appear 
for name,count in freq.items():
# check the count more than one time
    if count>1:
        print(f'{name} -> {count} times')
# Out:
# user1 -> 3 times
# user3 -> 2 times
